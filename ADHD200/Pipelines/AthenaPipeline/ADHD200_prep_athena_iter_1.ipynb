# %% [markdown]
# # ADHD200 — Подготовка данных (Athena .1D → TSV/NPY + манифесты)
#
# Функции этого ноутбука:
# 1) Сплющивание `Site/ID` → `sub-<lower(site)><ID>/func/`.
# 2) Конвертация `*.1D` → Z-score TSV + фиксированное окно NPY.
# 3) Поиск `*_bold.json` в BIDS и извлечение `RepetitionTime` (TR).
# 4) Валидация TR и длительности.
# 5) Агрегирование нескольких прогонов per-subject → `aggregate_manifest.csv`.

# %%
import os, re, json, shutil
import numpy as np, pandas as pd
from pathlib import Path
from IPython.display import display

# %%
# === Параметры подготовки ===

INPUT_ROOT = "./ADHD200_CC400_TCs_filtfix"    # структура Site/ID/*.1D
DEST_ROOT  = "./Athena_flat"                  # сюда ляжет sub-*/func/, TSV/NPY, манифесты

INPUT_ROOT = Path(INPUT_ROOT)
DEST_ROOT = Path(DEST_ROOT)

FLATTEN = True

PICK_VERSION = "filtered"    # 'filtered' | 'unfiltered' | 'any'  (Athena: 'sf*'~filtered, 'sn*'~unfiltered)
ZSCORE = True
WIN_TR = 120                 # длина окна на run; 0 — без обрезки/паддинга

BIDS_ROOT = "../RawDataBIDS"     # для *_bold.json и TR
COPY_BOLD_JSON = True

MIN_VOLS_TR = 60

WIN_TR_AGG = 240            # длина окна после агрегирования; 0 — без изменения
AGGREGATE_MODE = 'concat'   # 'concat' | 'mean'

# %% [markdown]
# ## Вспомогательные функции

# %%
def slug_site(s: str) -> str:
    return re.sub(r"[^a-z0-9]+", "", s.lower())

def ensure_dir(p: Path):
    p.mkdir(parents=True, exist_ok=True)

def is_filtered_filename(name: str) -> bool:
    base = os.path.basename(name)
    return base.startswith("sf")

def is_unfiltered_filename(name: str) -> bool:
    base = os.path.basename(name)
    return base.startswith("sn")

def pick_1d_files(files, pick_version: str):
    if pick_version == "filtered":
        return [f for f in files if is_filtered_filename(f.name)]
    if pick_version == "unfiltered":
        return [f for f in files if is_unfiltered_filename(f.name)]
    return files

def flatten_site_id(input_root: str, dest_root: str) -> pd.DataFrame:
    src = Path(input_root)
    dst = Path(dest_root)
    ensure_dir(dst)
    
    rows = []
    for site_dir in sorted([p for p in src.iterdir() if p.is_dir()]):
        site = site_dir.name
        for id_dir in sorted([p for p in site_dir.iterdir() if p.is_dir()]):
            sid = id_dir.name
            sub_label = f"sub-{slug_site(site)}{re.sub(r'[^0-9a-zA-Z]+','',sid)}"
            sub_root = dst / sub_label; sub_func = sub_root / "func"; ensure_dir(sub_func)
            one_ds = sorted(list(id_dir.glob("*.1D")))
            linked = []
            for f in one_ds:
                target = sub_func / f.name
                if not target.exists():
                    try:
                        os.symlink(os.path.abspath(f), target)
                    except OSError:
                        shutil.copy2(f, target)
                linked.append(target)
            if linked:
                rows.append({"participant_id": sub_label, "site": site, "id": sid, "one_d_paths": [str(p) for p in linked]})
    return pd.DataFrame(rows)

def load_1d(path: Path) -> np.ndarray:
    try:
        X = np.loadtxt(str(path), comments=['#','@'])
    except Exception:
        X = pd.read_csv(path, sep=r"\s+", header=None, comment="#", engine="python").values
    if X.ndim == 1:
        X = X[:, None]
    return X

def zscore_cols(X: np.ndarray) -> np.ndarray:
    mu = X.mean(axis=0, keepdims=True)
    sd = X.std(axis=0, ddof=1, keepdims=True) + 1e-8
    return (X - mu) / sd

def window_pad(X: np.ndarray, win: int) -> np.ndarray:
    if win <= 0: return X
    T, R = X.shape
    if T >= win: return X[:win]
    Y = np.zeros((win, R), dtype=X.dtype); Y[:T] = X
    return Y

def find_bold_json(bids_root: str, participant_id: str):
    if not bids_root: return None
    sub = Path(bids_root) / participant_id / "func"
    if sub.exists():
        cand = sorted(sub.glob("*_bold.json"))
        return cand[0] if cand else None
    for p in Path(bids_root).rglob(f"{participant_id}/func/*_bold.json"):
        return p
    return None

def extract_tr_from_json(json_path: Path):
    try:
        data = json.loads(json_path.read_text())
        tr = data.get("RepetitionTime")
        return float(tr) if tr is not None else None
    except Exception:
        return None

def convert_subject(sub_row, pick_version: str, out_root: Path, bids_root: str, copy_json: bool,
                    zscore=True, win_tr=120):
    participant_id = sub_row["participant_id"]
    out_sub = out_root / participant_id / "func"; ensure_dir(out_sub)
    files = [Path(p) for p in sub_row["one_d_paths"]]
    files = pick_1d_files(files, pick_version)
    results = []
    tr, bold_json_dst = None, None
    json_path = find_bold_json(bids_root, participant_id) if bids_root else None
    if json_path and Path(json_path).exists():
        tr = extract_tr_from_json(Path(json_path))
        if copy_json:
            bold_json_dst = out_sub / Path(json_path).name
            if not bold_json_dst.exists(): shutil.copy2(str(json_path), str(bold_json_dst))
    for f in files:
        X = load_1d(f); T, R = int(X.shape[0]), int(X.shape[1])
        print(f"Processing {f} for {participant_id}: T={T}, R={R}, TR={tr}")
        # Убедимся, что значения в X числовые
        if not np.issubdtype(X.dtype, np.number):
            # Преобразуем в числовой тип, заменяя нечисловые значения на NaN
            X = pd.DataFrame(X).apply(pd.to_numeric, errors='coerce').values
            # Удалим 2 первых столбца, если они NaN
            if R > 2 and np.isnan(X[:, 0]).all() and np.isnan(X[:, 1]).all():
                X = X[:, 2:]
                R = X.shape[1]
            # Удалим строки с NaN
            X = X[~np.isnan(X).any(axis=1)]
            T = X.shape[0]
        # Пропускаем файлы с недостаточным количеством временных точек
        if tr and (MIN_VOLS_TR > 0) and (T * tr < MIN_VOLS_TR):
            print(f"Skipping {f} for {participant_id}: T={T}, TR={tr} => total time {T*tr:.1f}s < {MIN_VOLS_TR}s")
            continue
        # # Агрегируем по времени, если нужно
        # if WIN_TR_AGG > 0 and AGGREGATE_MODE == 'concat' and tr:
        #     target_T = int(WIN_TR_AGG / tr)
        #     if T > target_T:
        #         n_segments = T // target_T
        #         X = X[:n_segments * target_T].reshape(n_segments, target_T, R).mean(axis=0)
        #         T = X.shape[0]
        Xz = zscore_cols(X) if zscore else X
        Xw = window_pad(Xz, win_tr) if win_tr else Xz
        stem = f.stem
        tsv_path = out_sub / f"{stem}_znorm.tsv"
        npy_path = out_sub / (f"{stem}_znorm_{win_tr}tr.npy" if win_tr else f"{stem}_znorm.npy")
        pd.DataFrame(Xz, columns=[f"roi_{i+1}" for i in range(R)]).to_csv(tsv_path, sep="\t", index=False)
        np.save(npy_path, Xw)
        results.append({
            "participant_id": participant_id,
            "file": str(f),
            "tsv_path": str(tsv_path),
            "npy_path": str(npy_path),
            "T": T, "R": R,
            "filter_version": ("filtered" if is_filtered_filename(f.name) else ("unfiltered" if is_unfiltered_filename(f.name) else "unknown")),
            "TR": tr,
            "bold_json": str(bold_json_dst) if bold_json_dst else (str(json_path) if json_path else "")
        })
    return results

# %% [markdown]
# ## 1) Сплющивание и сбор списка файлов

# %%
# Удаляем старые данные
shutil.rmtree(DEST_ROOT)
# Создаем корневую директорию для выходных данных
DEST_ROOT.mkdir(parents=True)

if FLATTEN:
    subs_df = flatten_site_id(str(INPUT_ROOT), str(DEST_ROOT))
else:
    rows = []
    for sub in sorted(DEST_ROOT.glob("sub-*/func")):
        one_ds = sorted(sub.glob("*.1D"))
        if one_ds:
            rows.append({"participant_id": sub.parent.name, "site": "", "id": "", "one_d_paths": [str(p) for p in one_ds]})
    subs_df = pd.DataFrame(rows)
print("Найдено субъектов:", len(subs_df))
display(subs_df.head())
# Out:
# Найдено субъектов: 776
#    participant_id site       id  \
# 0  sub-kki1018959  KKI  1018959
# 1  sub-kki1019436  KKI  1019436
# 2  sub-kki1043241  KKI  1043241
# 3  sub-kki1266183  KKI  1266183
# 4  sub-kki1535233  KKI  1535233
#
#                                          one_d_paths
# 0  [Athena_flat/sub-kki1018959/func/sfnwmrda10189...
# 1  [Athena_flat/sub-kki1019436/func/sfnwmrda10194...
# 2  [Athena_flat/sub-kki1043241/func/sfnwmrda10432...
# 3  [Athena_flat/sub-kki1266183/func/sfnwmrda12661...
# 4  [Athena_flat/sub-kki1535233/func/sfnwmrda15352...

# %%
# Преобразуем один тестовый файл

# --- IGNORE ---
# Создаем корневую директорию для выходных данных
test_dest = DEST_ROOT / "test_subject"
shutil.rmtree(test_dest, ignore_errors=True)
ensure_dir(test_dest)

test_row = subs_df.iloc[0]
test_results = convert_subject(
    test_row,
    PICK_VERSION,
    test_dest,
    BIDS_ROOT,
    COPY_BOLD_JSON,
    zscore=ZSCORE,
    win_tr=WIN_TR
)
# --- IGNORE ---
print("Тестовое преобразование одного субъекта:")
display(pd.DataFrame(test_results))
# Out:
# Processing Athena_flat/sub-kki1018959/func/sfnwmrda1018959_session_1_rest_1_cc400_TCs.1D for sub-kki1018959: T=149, R=353, TR=None
# Тестовое преобразование одного субъекта:
#    participant_id                                               file  \
# 0  sub-kki1018959  Athena_flat/sub-kki1018959/func/sfnwmrda101895...
#
#                                             tsv_path  \
# 0  Athena_flat/test_subject/sub-kki1018959/func/s...
#
#                                             npy_path    T    R filter_version  \
# 0  Athena_flat/test_subject/sub-kki1018959/func/s...  148  351       filtered
#
#      TR bold_json
# 0  None

# %% [markdown]
# ## 2) Конвертация .1D → NPY/TSV и сборка manifest.csv

# %%
out_root = DEST_ROOT if isinstance(DEST_ROOT, Path) else Path(str(DEST_ROOT))
print("Вывод в:", out_root)

# Сбор конвертаций
all_rows = []
for _, row in subs_df.iterrows():
    rows = convert_subject(
        row,
        PICK_VERSION,
        out_root,
        BIDS_ROOT,
        COPY_BOLD_JSON,
        zscore=ZSCORE,
        win_tr=WIN_TR
    )
    all_rows.extend(rows)

# Формирование и сохранение manifest
manifest = pd.DataFrame(all_rows)
man_path = out_root / "manifest.csv"
manifest.to_csv(man_path, index=False)
print("Сохранён manifest:", man_path)
display(manifest.head())
print("Всего рядов:", len(manifest))
# Out:
# Вывод в: Athena_flat
# Processing Athena_flat/sub-kki1018959/func/sfnwmrda1018959_session_1_rest_1_cc400_TCs.1D for sub-kki1018959: T=149, R=353, TR=None
# Processing Athena_flat/sub-kki1019436/func/sfnwmrda1019436_session_1_rest_1_cc400_TCs.1D for sub-kki1019436: T=149, R=353, TR=None
# Processing Athena_flat/sub-kki1043241/func/sfnwmrda1043241_session_1_rest_1_cc400_TCs.1D for sub-kki1043241: T=149, R=353, TR=None
# Processing Athena_flat/sub-kki1266183/func/sfnwmrda1266183_session_1_rest_1_cc400_TCs.1D for sub-kki1266183: T=121, R=353, TR=None
# Processing Athena_flat/sub-kki1535233/func/sfnwmrda1535233_session_1_rest_1_cc400_TCs.1D for sub-kki1535233: T=149, R=353, TR=None
# Processing Athena_flat/sub-kki1541812/func/sfnwmrda1541812_session_1_rest_1_cc400_TCs.1D for sub-kki1541812: T=121, R=353, TR=None
# Processing Athena_flat/sub-kki1577042/func/sfnwmrda1577042_session_1_rest_1_cc400_TCs.1D for sub-kki1577042: T=121, R=353, TR=None
# Processing Athena_flat/sub-kki1594156/func/sfnwmrda1594156_session_1_rest_1_cc400_TCs.1D for sub-kki1594156: T=121, R=353, TR=None
# Processing Athena_flat/sub-kki1623716/func/sfnwmrda1623716_session_1_rest_1_cc400_TCs.1D for sub-kki1623716: T=121, R=353, TR=None
# Processing Athena_flat/sub-kki1638334/func/sfnwmrda1638334_session_1_rest_1_cc400_TCs.1D for sub-kki1638334: T=121, R=353, TR=None
# Processing Athena_flat/sub-kki1652369/func/sfnwmrda1652369_session_1_rest_1_cc400_TCs.1D for sub-kki1652369: T=121, R=353, TR=None
# Processing Athena_flat/sub-kki1686265/func/sfnwmrda1686265_session_1_rest_1_cc400_TCs.1D for sub-kki1686265: T=121, R=353, TR=None
# Processing Athena_flat/sub-kki1692275/func/sfnwmrda1692275_session_1_rest_1_cc400_TCs.1D for sub-kki1692275: T=121, R=353, TR=None
# Processing Athena_flat/sub-kki1735881/func/sfnwmrda1735881_session_1_rest_1_cc400_TCs.1D for sub-kki1735881: T=121, R=353, TR=None
# Processing Athena_flat/sub-kki1779922/func/sfnwmrda1779922_session_1_rest_1_cc400_TCs.1D for sub-kki1779922: T=149, R=353, TR=None
# Processing Athena_flat/sub-kki1842819/func/sfnwmrda1842819_session_1_rest_1_cc400_TCs.1D for sub-kki1842819: T=121, R=353, TR=None
# Processing Athena_flat/sub-kki1846346/func/sfnwmrda1846346_session_1_rest_1_cc400_TCs.1D for sub-kki1846346: T=149, R=353, TR=None
# Processing Athena_flat/sub-kki1873761/func/sfnwmrda1873761_session_1_rest_1_cc400_TCs.1D for sub-kki1873761: T=121, R=353, TR=None
# Processing Athena_flat/sub-kki1962503/func/sfnwmrda1962503_session_1_rest_1_cc400_TCs.1D for sub-kki1962503: T=121, R=353, TR=None
# Processing Athena_flat/sub-kki1988015/func/sfnwmrda1988015_session_1_rest_1_cc400_TCs.1D for sub-kki1988015: T=149, R=353, TR=None
# Processing Athena_flat/sub-kki1996183/func/sfnwmrda1996183_session_1_rest_1_cc400_TCs.1D for sub-kki1996183: T=149, R=353, TR=None
# Processing Athena_flat/sub-kki2014113/func/sfnwmrda2014113_session_1_rest_1_cc400_TCs.1D for sub-kki2014113: T=121, R=353, TR=None
# Processing Athena_flat/sub-kki2018106/func/sfnwmrda2018106_session_1_rest_1_cc400_TCs.1D for sub-kki2018106: T=149, R=353, TR=None
# Processing Athena_flat/sub-kki2026113/func/sfnwmrda2026113_session_1_rest_1_cc400_TCs.1D for sub-kki2026113: T=121, R=353, TR=None
# Processing Athena_flat/sub-kki2081148/func/sfnwmrda2081148_session_1_rest_1_cc400_TCs.1D for sub-kki2081148: T=121, R=353, TR=None
# Processing Athena_flat/sub-kki2104012/func/sfnwmrda2104012_session_1_rest_1_cc400_TCs.1D for sub-kki2104012: T=121, R=353, TR=None
# Processing Athena_flat/sub-kki2138826/func/sfnwmrda2138826_session_1_rest_1_cc400_TCs.1D for sub-kki2138826: T=121, R=353, TR=None
# Processing Athena_flat/sub-kki2299519/func/sfnwmrda2299519_session_1_rest_1_cc400_TCs.1D for sub-kki2299519: T=121, R=353, TR=None
# Processing Athena_flat/sub-kki2344857/func/sfnwmrda2344857_session_1_rest_1_cc400_TCs.1D for sub-kki2344857: T=149, R=353, TR=None
# Processing Athena_flat/sub-kki2360428/func/sfnwmrda2360428_session_1_rest_1_cc400_TCs.1D for sub-kki2360428: T=121, R=353, TR=None
# Processing Athena_flat/sub-kki2371032/func/sfnwmrda2371032_session_1_rest_1_cc400_TCs.1D for sub-kki2371032: T=149, R=353, TR=None
# Processing Athena_flat/sub-kki2554127/func/sfnwmrda2554127_session_1_rest_1_cc400_TCs.1D for sub-kki2554127: T=121, R=353, TR=None
# Processing Athena_flat/sub-kki2558999/func/sfnwmrda2558999_session_1_rest_1_cc400_TCs.1D for sub-kki2558999: T=149, R=353, TR=None
# Processing Athena_flat/sub-kki2572285/func/sfnwmrda2572285_session_1_rest_1_cc400_TCs.1D for sub-kki2572285: T=149, R=353, TR=None
# Processing Athena_flat/sub-kki2601925/func/sfnwmrda2601925_session_1_rest_1_cc400_TCs.1D for sub-kki2601925: T=121, R=353, TR=None
# Processing Athena_flat/sub-kki2618929/func/sfnwmrda2618929_session_1_rest_1_cc400_TCs.1D for sub-kki2618929: T=121, R=353, TR=None
# Processing Athena_flat/sub-kki2621228/func/sfnwmrda2621228_session_1_rest_1_cc400_TCs.1D for sub-kki2621228: T=121, R=353, TR=None
# Processing Athena_flat/sub-kki2640795/func/sfnwmrda2640795_session_1_rest_1_cc400_TCs.1D for sub-kki2640795: T=121, R=353, TR=None
# Processing Athena_flat/sub-kki2641332/func/sfnwmrda2641332_session_1_rest_1_cc400_TCs.1D for sub-kki2641332: T=149, R=353, TR=None
# Processing Athena_flat/sub-kki2703289/func/sfnwmrda2703289_session_1_rest_1_cc400_TCs.1D for sub-kki2703289: T=121, R=353, TR=None
# Processing Athena_flat/sub-kki2740232/func/sfnwmrda2740232_session_1_rest_1_cc400_TCs.1D for sub-kki2740232: T=121, R=353, TR=None
# Processing Athena_flat/sub-kki2768273/func/sfnwmrda2768273_session_1_rest_1_cc400_TCs.1D for sub-kki2768273: T=121, R=353, TR=None
# Processing Athena_flat/sub-kki2822304/func/sfnwmrda2822304_session_1_rest_1_cc400_TCs.1D for sub-kki2822304: T=121, R=353, TR=None
# Processing Athena_flat/sub-kki2903997/func/sfnwmrda2903997_session_1_rest_1_cc400_TCs.1D for sub-kki2903997: T=149, R=353, TR=None
# Processing Athena_flat/sub-kki2917777/func/sfnwmrda2917777_session_1_rest_1_cc400_TCs.1D for sub-kki2917777: T=149, R=353, TR=None
# Processing Athena_flat/sub-kki2930625/func/sfnwmrda2930625_session_1_rest_1_cc400_TCs.1D for sub-kki2930625: T=121, R=353, TR=None
# Processing Athena_flat/sub-kki3103809/func/sfnwmrda3103809_session_1_rest_1_cc400_TCs.1D for sub-kki3103809: T=149, R=353, TR=None
# Processing Athena_flat/sub-kki3119327/func/sfnwmrda3119327_session_1_rest_1_cc400_TCs.1D for sub-kki3119327: T=149, R=353, TR=None
# Processing Athena_flat/sub-kki3154996/func/sfnwmrda3154996_session_1_rest_1_cc400_TCs.1D for sub-kki3154996: T=121, R=353, TR=None
# Processing Athena_flat/sub-kki3160561/func/sfnwmrda3160561_session_1_rest_1_cc400_TCs.1D for sub-kki3160561: T=149, R=353, TR=None
# Processing Athena_flat/sub-kki3170319/func/sfnwmrda3170319_session_1_rest_1_cc400_TCs.1D for sub-kki3170319: T=121, R=353, TR=None
# Processing Athena_flat/sub-kki3310328/func/sfnwmrda3310328_session_1_rest_1_cc400_TCs.1D for sub-kki3310328: T=121, R=353, TR=None
# Processing Athena_flat/sub-kki3434578/func/sfnwmrda3434578_session_1_rest_1_cc400_TCs.1D for sub-kki3434578: T=149, R=353, TR=None
# Processing Athena_flat/sub-kki3486975/func/sfnwmrda3486975_session_1_rest_1_cc400_TCs.1D for sub-kki3486975: T=121, R=353, TR=None
# Processing Athena_flat/sub-kki3519022/func/sfnwmrda3519022_session_1_rest_1_cc400_TCs.1D for sub-kki3519022: T=121, R=353, TR=None
# Processing Athena_flat/sub-kki3611827/func/sfnwmrda3611827_session_1_rest_1_cc400_TCs.1D for sub-kki3611827: T=121, R=353, TR=None
# Processing Athena_flat/sub-kki3699991/func/sfnwmrda3699991_session_1_rest_1_cc400_TCs.1D for sub-kki3699991: T=149, R=353, TR=None
# Processing Athena_flat/sub-kki3713230/func/sfnwmrda3713230_session_1_rest_1_cc400_TCs.1D for sub-kki3713230: T=121, R=353, TR=None
# Processing Athena_flat/sub-kki3813783/func/sfnwmrda3813783_session_1_rest_1_cc400_TCs.1D for sub-kki3813783: T=121, R=353, TR=None
# Processing Athena_flat/sub-kki3884955/func/sfnwmrda3884955_session_1_rest_1_cc400_TCs.1D for sub-kki3884955: T=121, R=353, TR=None
# Processing Athena_flat/sub-kki3902469/func/sfnwmrda3902469_session_1_rest_1_cc400_TCs.1D for sub-kki3902469: T=149, R=353, TR=None
# Processing Athena_flat/sub-kki3912996/func/sfnwmrda3912996_session_1_rest_1_cc400_TCs.1D for sub-kki3912996: T=121, R=353, TR=None
# Processing Athena_flat/sub-kki3917422/func/sfnwmrda3917422_session_1_rest_1_cc400_TCs.1D for sub-kki3917422: T=121, R=353, TR=None
# Processing Athena_flat/sub-kki3972472/func/sfnwmrda3972472_session_1_rest_1_cc400_TCs.1D for sub-kki3972472: T=121, R=353, TR=None
# Processing Athena_flat/sub-kki3972956/func/sfnwmrda3972956_session_1_rest_1_cc400_TCs.1D for sub-kki3972956: T=121, R=353, TR=None
# Processing Athena_flat/sub-kki4104523/func/sfnwmrda4104523_session_1_rest_1_cc400_TCs.1D for sub-kki4104523: T=149, R=353, TR=None
# Processing Athena_flat/sub-kki4154182/func/sfnwmrda4154182_session_1_rest_1_cc400_TCs.1D for sub-kki4154182: T=149, R=353, TR=None
# Processing Athena_flat/sub-kki4275075/func/sfnwmrda4275075_session_1_rest_1_cc400_TCs.1D for sub-kki4275075: T=121, R=353, TR=None
# Processing Athena_flat/sub-kki4362730/func/sfnwmrda4362730_session_1_rest_1_cc400_TCs.1D for sub-kki4362730: T=121, R=353, TR=None
# Processing Athena_flat/sub-kki4601682/func/sfnwmrda4601682_session_1_rest_1_cc400_TCs.1D for sub-kki4601682: T=121, R=353, TR=None
# Processing Athena_flat/sub-kki5216908/func/sfnwmrda5216908_session_1_rest_1_cc400_TCs.1D for sub-kki5216908: T=149, R=353, TR=None
# Processing Athena_flat/sub-kki6346605/func/sfnwmrda6346605_session_1_rest_1_cc400_TCs.1D for sub-kki6346605: T=121, R=353, TR=None
# Processing Athena_flat/sub-kki6453038/func/sfnwmrda6453038_session_1_rest_1_cc400_TCs.1D for sub-kki6453038: T=121, R=353, TR=None
# Processing Athena_flat/sub-kki7129258/func/sfnwmrda7129258_session_1_rest_1_cc400_TCs.1D for sub-kki7129258: T=121, R=353, TR=None
# Processing Athena_flat/sub-kki7415617/func/sfnwmrda7415617_session_1_rest_1_cc400_TCs.1D for sub-kki7415617: T=121, R=353, TR=None
# Processing Athena_flat/sub-kki7774305/func/sfnwmrda7774305_session_1_rest_1_cc400_TCs.1D for sub-kki7774305: T=149, R=353, TR=None
# Processing Athena_flat/sub-kki8083695/func/sfnwmrda8083695_session_1_rest_1_cc400_TCs.1D for sub-kki8083695: T=121, R=353, TR=None
# Processing Athena_flat/sub-kki8263351/func/sfnwmrda8263351_session_1_rest_1_cc400_TCs.1D for sub-kki8263351: T=121, R=353, TR=None
# Processing Athena_flat/sub-kki8337695/func/sfnwmrda8337695_session_1_rest_1_cc400_TCs.1D for sub-kki8337695: T=149, R=353, TR=None
# Processing Athena_flat/sub-kki8432725/func/sfnwmrda8432725_session_1_rest_1_cc400_TCs.1D for sub-kki8432725: T=121, R=353, TR=None
# Processing Athena_flat/sub-kki8628223/func/sfnwmrda8628223_session_1_rest_1_cc400_TCs.1D for sub-kki8628223: T=149, R=353, TR=None
# Processing Athena_flat/sub-kki8658218/func/sfnwmrda8658218_session_1_rest_1_cc400_TCs.1D for sub-kki8658218: T=121, R=353, TR=None
# Processing Athena_flat/sub-kki9922944/func/sfnwmrda9922944_session_1_rest_1_cc400_TCs.1D for sub-kki9922944: T=149, R=353, TR=None
# Processing Athena_flat/sub-nyu0010001/func/sfnwmrda0010001_session_1_rest_1_cc400_TCs.1D for sub-nyu0010001: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010001/func/sfnwmrda0010001_session_1_rest_2_cc400_TCs.1D for sub-nyu0010001: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010002/func/sfnwmrda0010002_session_1_rest_1_cc400_TCs.1D for sub-nyu0010002: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010002/func/sfnwmrda0010002_session_1_rest_2_cc400_TCs.1D for sub-nyu0010002: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010003/func/sfnwmrda0010003_session_1_rest_1_cc400_TCs.1D for sub-nyu0010003: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010004/func/sfnwmrda0010004_session_1_rest_1_cc400_TCs.1D for sub-nyu0010004: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010004/func/sfnwmrda0010004_session_1_rest_2_cc400_TCs.1D for sub-nyu0010004: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010005/func/sfnwmrda0010005_session_1_rest_1_cc400_TCs.1D for sub-nyu0010005: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010006/func/sfnwmrda0010006_session_1_rest_1_cc400_TCs.1D for sub-nyu0010006: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010007/func/sfnwmrda0010007_session_1_rest_1_cc400_TCs.1D for sub-nyu0010007: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010007/func/sfnwmrda0010007_session_1_rest_2_cc400_TCs.1D for sub-nyu0010007: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010008/func/sfnwmrda0010008_session_1_rest_1_cc400_TCs.1D for sub-nyu0010008: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010008/func/sfnwmrda0010008_session_1_rest_2_cc400_TCs.1D for sub-nyu0010008: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010009/func/sfnwmrda0010009_session_1_rest_1_cc400_TCs.1D for sub-nyu0010009: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010009/func/sfnwmrda0010009_session_1_rest_2_cc400_TCs.1D for sub-nyu0010009: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010010/func/sfnwmrda0010010_session_1_rest_1_cc400_TCs.1D for sub-nyu0010010: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010010/func/sfnwmrda0010010_session_1_rest_2_cc400_TCs.1D for sub-nyu0010010: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010011/func/sfnwmrda0010011_session_1_rest_1_cc400_TCs.1D for sub-nyu0010011: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010011/func/sfnwmrda0010011_session_1_rest_2_cc400_TCs.1D for sub-nyu0010011: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010012/func/sfnwmrda0010012_session_1_rest_1_cc400_TCs.1D for sub-nyu0010012: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010012/func/sfnwmrda0010012_session_1_rest_2_cc400_TCs.1D for sub-nyu0010012: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010013/func/sfnwmrda0010013_session_1_rest_1_cc400_TCs.1D for sub-nyu0010013: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010013/func/sfnwmrda0010013_session_1_rest_2_cc400_TCs.1D for sub-nyu0010013: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010014/func/sfnwmrda0010014_session_1_rest_1_cc400_TCs.1D for sub-nyu0010014: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010014/func/sfnwmrda0010014_session_1_rest_2_cc400_TCs.1D for sub-nyu0010014: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010015/func/sfnwmrda0010015_session_1_rest_1_cc400_TCs.1D for sub-nyu0010015: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010015/func/sfnwmrda0010015_session_1_rest_2_cc400_TCs.1D for sub-nyu0010015: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010017/func/sfnwmrda0010017_session_1_rest_1_cc400_TCs.1D for sub-nyu0010017: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010017/func/sfnwmrda0010017_session_1_rest_2_cc400_TCs.1D for sub-nyu0010017: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010018/func/sfnwmrda0010018_session_1_rest_1_cc400_TCs.1D for sub-nyu0010018: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010019/func/sfnwmrda0010019_session_1_rest_1_cc400_TCs.1D for sub-nyu0010019: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010019/func/sfnwmrda0010019_session_1_rest_2_cc400_TCs.1D for sub-nyu0010019: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010020/func/sfnwmrda0010020_session_1_rest_1_cc400_TCs.1D for sub-nyu0010020: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010021/func/sfnwmrda0010021_session_1_rest_1_cc400_TCs.1D for sub-nyu0010021: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010021/func/sfnwmrda0010021_session_1_rest_2_cc400_TCs.1D for sub-nyu0010021: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010022/func/sfnwmrda0010022_session_1_rest_1_cc400_TCs.1D for sub-nyu0010022: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010022/func/sfnwmrda0010022_session_1_rest_2_cc400_TCs.1D for sub-nyu0010022: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010023/func/sfnwmrda0010023_session_1_rest_1_cc400_TCs.1D for sub-nyu0010023: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010023/func/sfnwmrda0010023_session_1_rest_2_cc400_TCs.1D for sub-nyu0010023: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010024/func/sfnwmrda0010024_session_1_rest_1_cc400_TCs.1D for sub-nyu0010024: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010024/func/sfnwmrda0010024_session_1_rest_2_cc400_TCs.1D for sub-nyu0010024: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010025/func/sfnwmrda0010025_session_1_rest_1_cc400_TCs.1D for sub-nyu0010025: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010025/func/sfnwmrda0010025_session_1_rest_2_cc400_TCs.1D for sub-nyu0010025: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010026/func/sfnwmrda0010026_session_1_rest_1_cc400_TCs.1D for sub-nyu0010026: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010026/func/sfnwmrda0010026_session_1_rest_2_cc400_TCs.1D for sub-nyu0010026: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010028/func/sfnwmrda0010028_session_1_rest_1_cc400_TCs.1D for sub-nyu0010028: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010028/func/sfnwmrda0010028_session_1_rest_2_cc400_TCs.1D for sub-nyu0010028: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010029/func/sfnwmrda0010029_session_1_rest_1_cc400_TCs.1D for sub-nyu0010029: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010029/func/sfnwmrda0010029_session_1_rest_2_cc400_TCs.1D for sub-nyu0010029: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010030/func/sfnwmrda0010030_session_1_rest_1_cc400_TCs.1D for sub-nyu0010030: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010030/func/sfnwmrda0010030_session_1_rest_2_cc400_TCs.1D for sub-nyu0010030: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010031/func/sfnwmrda0010031_session_1_rest_1_cc400_TCs.1D for sub-nyu0010031: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010032/func/sfnwmrda0010032_session_1_rest_1_cc400_TCs.1D for sub-nyu0010032: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010033/func/sfnwmrda0010033_session_1_rest_1_cc400_TCs.1D for sub-nyu0010033: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010033/func/sfnwmrda0010033_session_1_rest_2_cc400_TCs.1D for sub-nyu0010033: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010034/func/sfnwmrda0010034_session_1_rest_1_cc400_TCs.1D for sub-nyu0010034: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010034/func/sfnwmrda0010034_session_1_rest_2_cc400_TCs.1D for sub-nyu0010034: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010035/func/sfnwmrda0010035_session_1_rest_1_cc400_TCs.1D for sub-nyu0010035: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010035/func/sfnwmrda0010035_session_1_rest_2_cc400_TCs.1D for sub-nyu0010035: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010036/func/sfnwmrda0010036_session_1_rest_1_cc400_TCs.1D for sub-nyu0010036: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010037/func/sfnwmrda0010037_session_1_rest_1_cc400_TCs.1D for sub-nyu0010037: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010037/func/sfnwmrda0010037_session_1_rest_2_cc400_TCs.1D for sub-nyu0010037: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010038/func/sfnwmrda0010038_session_1_rest_1_cc400_TCs.1D for sub-nyu0010038: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010038/func/sfnwmrda0010038_session_1_rest_2_cc400_TCs.1D for sub-nyu0010038: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010039/func/sfnwmrda0010039_session_1_rest_1_cc400_TCs.1D for sub-nyu0010039: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010039/func/sfnwmrda0010039_session_1_rest_2_cc400_TCs.1D for sub-nyu0010039: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010040/func/sfnwmrda0010040_session_1_rest_1_cc400_TCs.1D for sub-nyu0010040: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010040/func/sfnwmrda0010040_session_1_rest_2_cc400_TCs.1D for sub-nyu0010040: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010041/func/sfnwmrda0010041_session_1_rest_1_cc400_TCs.1D for sub-nyu0010041: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010042/func/sfnwmrda0010042_session_1_rest_1_cc400_TCs.1D for sub-nyu0010042: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010043/func/sfnwmrda0010043_session_1_rest_1_cc400_TCs.1D for sub-nyu0010043: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010043/func/sfnwmrda0010043_session_1_rest_2_cc400_TCs.1D for sub-nyu0010043: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010044/func/sfnwmrda0010044_session_1_rest_1_cc400_TCs.1D for sub-nyu0010044: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010044/func/sfnwmrda0010044_session_1_rest_2_cc400_TCs.1D for sub-nyu0010044: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010045/func/sfnwmrda0010045_session_1_rest_1_cc400_TCs.1D for sub-nyu0010045: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010045/func/sfnwmrda0010045_session_1_rest_2_cc400_TCs.1D for sub-nyu0010045: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010046/func/sfnwmrda0010046_session_1_rest_1_cc400_TCs.1D for sub-nyu0010046: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010046/func/sfnwmrda0010046_session_1_rest_2_cc400_TCs.1D for sub-nyu0010046: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010047/func/sfnwmrda0010047_session_1_rest_1_cc400_TCs.1D for sub-nyu0010047: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010048/func/sfnwmrda0010048_session_1_rest_1_cc400_TCs.1D for sub-nyu0010048: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010048/func/sfnwmrda0010048_session_1_rest_2_cc400_TCs.1D for sub-nyu0010048: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010049/func/sfnwmrda0010049_session_1_rest_1_cc400_TCs.1D for sub-nyu0010049: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010050/func/sfnwmrda0010050_session_1_rest_1_cc400_TCs.1D for sub-nyu0010050: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010050/func/sfnwmrda0010050_session_1_rest_2_cc400_TCs.1D for sub-nyu0010050: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010051/func/sfnwmrda0010051_session_1_rest_1_cc400_TCs.1D for sub-nyu0010051: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010051/func/sfnwmrda0010051_session_1_rest_2_cc400_TCs.1D for sub-nyu0010051: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010052/func/sfnwmrda0010052_session_1_rest_1_cc400_TCs.1D for sub-nyu0010052: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010052/func/sfnwmrda0010052_session_1_rest_2_cc400_TCs.1D for sub-nyu0010052: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010053/func/sfnwmrda0010053_session_1_rest_1_cc400_TCs.1D for sub-nyu0010053: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010053/func/sfnwmrda0010053_session_1_rest_2_cc400_TCs.1D for sub-nyu0010053: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010054/func/sfnwmrda0010054_session_1_rest_1_cc400_TCs.1D for sub-nyu0010054: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010054/func/sfnwmrda0010054_session_1_rest_2_cc400_TCs.1D for sub-nyu0010054: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010056/func/sfnwmrda0010056_session_1_rest_1_cc400_TCs.1D for sub-nyu0010056: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010056/func/sfnwmrda0010056_session_1_rest_2_cc400_TCs.1D for sub-nyu0010056: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010057/func/sfnwmrda0010057_session_1_rest_1_cc400_TCs.1D for sub-nyu0010057: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010057/func/sfnwmrda0010057_session_1_rest_2_cc400_TCs.1D for sub-nyu0010057: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010058/func/sfnwmrda0010058_session_1_rest_1_cc400_TCs.1D for sub-nyu0010058: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010058/func/sfnwmrda0010058_session_1_rest_2_cc400_TCs.1D for sub-nyu0010058: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010059/func/sfnwmrda0010059_session_1_rest_1_cc400_TCs.1D for sub-nyu0010059: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010059/func/sfnwmrda0010059_session_1_rest_2_cc400_TCs.1D for sub-nyu0010059: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010060/func/sfnwmrda0010060_session_1_rest_1_cc400_TCs.1D for sub-nyu0010060: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010061/func/sfnwmrda0010061_session_1_rest_1_cc400_TCs.1D for sub-nyu0010061: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010062/func/sfnwmrda0010062_session_1_rest_1_cc400_TCs.1D for sub-nyu0010062: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010062/func/sfnwmrda0010062_session_1_rest_2_cc400_TCs.1D for sub-nyu0010062: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010063/func/sfnwmrda0010063_session_1_rest_1_cc400_TCs.1D for sub-nyu0010063: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010063/func/sfnwmrda0010063_session_1_rest_2_cc400_TCs.1D for sub-nyu0010063: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010064/func/sfnwmrda0010064_session_1_rest_1_cc400_TCs.1D for sub-nyu0010064: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010065/func/sfnwmrda0010065_session_1_rest_1_cc400_TCs.1D for sub-nyu0010065: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010065/func/sfnwmrda0010065_session_1_rest_2_cc400_TCs.1D for sub-nyu0010065: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010066/func/sfnwmrda0010066_session_1_rest_1_cc400_TCs.1D for sub-nyu0010066: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010066/func/sfnwmrda0010066_session_1_rest_2_cc400_TCs.1D for sub-nyu0010066: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010067/func/sfnwmrda0010067_session_1_rest_1_cc400_TCs.1D for sub-nyu0010067: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010067/func/sfnwmrda0010067_session_1_rest_2_cc400_TCs.1D for sub-nyu0010067: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010068/func/sfnwmrda0010068_session_1_rest_1_cc400_TCs.1D for sub-nyu0010068: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010068/func/sfnwmrda0010068_session_1_rest_2_cc400_TCs.1D for sub-nyu0010068: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010069/func/sfnwmrda0010069_session_1_rest_1_cc400_TCs.1D for sub-nyu0010069: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010069/func/sfnwmrda0010069_session_1_rest_2_cc400_TCs.1D for sub-nyu0010069: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010070/func/sfnwmrda0010070_session_1_rest_1_cc400_TCs.1D for sub-nyu0010070: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010070/func/sfnwmrda0010070_session_1_rest_2_cc400_TCs.1D for sub-nyu0010070: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010071/func/sfnwmrda0010071_session_1_rest_1_cc400_TCs.1D for sub-nyu0010071: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010071/func/sfnwmrda0010071_session_1_rest_2_cc400_TCs.1D for sub-nyu0010071: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010072/func/sfnwmrda0010072_session_1_rest_1_cc400_TCs.1D for sub-nyu0010072: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010073/func/sfnwmrda0010073_session_1_rest_1_cc400_TCs.1D for sub-nyu0010073: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010073/func/sfnwmrda0010073_session_1_rest_2_cc400_TCs.1D for sub-nyu0010073: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010074/func/sfnwmrda0010074_session_1_rest_1_cc400_TCs.1D for sub-nyu0010074: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010075/func/sfnwmrda0010075_session_1_rest_1_cc400_TCs.1D for sub-nyu0010075: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010075/func/sfnwmrda0010075_session_1_rest_2_cc400_TCs.1D for sub-nyu0010075: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010076/func/sfnwmrda0010076_session_1_rest_1_cc400_TCs.1D for sub-nyu0010076: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010076/func/sfnwmrda0010076_session_1_rest_2_cc400_TCs.1D for sub-nyu0010076: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010077/func/sfnwmrda0010077_session_1_rest_1_cc400_TCs.1D for sub-nyu0010077: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010077/func/sfnwmrda0010077_session_1_rest_2_cc400_TCs.1D for sub-nyu0010077: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010078/func/sfnwmrda0010078_session_1_rest_1_cc400_TCs.1D for sub-nyu0010078: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010078/func/sfnwmrda0010078_session_1_rest_2_cc400_TCs.1D for sub-nyu0010078: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010079/func/sfnwmrda0010079_session_1_rest_1_cc400_TCs.1D for sub-nyu0010079: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010079/func/sfnwmrda0010079_session_1_rest_2_cc400_TCs.1D for sub-nyu0010079: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010080/func/sfnwmrda0010080_session_1_rest_1_cc400_TCs.1D for sub-nyu0010080: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010080/func/sfnwmrda0010080_session_1_rest_2_cc400_TCs.1D for sub-nyu0010080: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010081/func/sfnwmrda0010081_session_1_rest_1_cc400_TCs.1D for sub-nyu0010081: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010081/func/sfnwmrda0010081_session_1_rest_2_cc400_TCs.1D for sub-nyu0010081: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010082/func/sfnwmrda0010082_session_1_rest_1_cc400_TCs.1D for sub-nyu0010082: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010082/func/sfnwmrda0010082_session_1_rest_2_cc400_TCs.1D for sub-nyu0010082: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010083/func/sfnwmrda0010083_session_1_rest_1_cc400_TCs.1D for sub-nyu0010083: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010083/func/sfnwmrda0010083_session_1_rest_2_cc400_TCs.1D for sub-nyu0010083: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010084/func/sfnwmrda0010084_session_1_rest_1_cc400_TCs.1D for sub-nyu0010084: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010084/func/sfnwmrda0010084_session_1_rest_2_cc400_TCs.1D for sub-nyu0010084: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010085/func/sfnwmrda0010085_session_1_rest_1_cc400_TCs.1D for sub-nyu0010085: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010085/func/sfnwmrda0010085_session_1_rest_2_cc400_TCs.1D for sub-nyu0010085: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010086/func/sfnwmrda0010086_session_1_rest_1_cc400_TCs.1D for sub-nyu0010086: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010086/func/sfnwmrda0010086_session_1_rest_2_cc400_TCs.1D for sub-nyu0010086: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010087/func/sfnwmrda0010087_session_1_rest_1_cc400_TCs.1D for sub-nyu0010087: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010087/func/sfnwmrda0010087_session_1_rest_2_cc400_TCs.1D for sub-nyu0010087: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010088/func/sfnwmrda0010088_session_1_rest_1_cc400_TCs.1D for sub-nyu0010088: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010088/func/sfnwmrda0010088_session_1_rest_2_cc400_TCs.1D for sub-nyu0010088: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010089/func/sfnwmrda0010089_session_1_rest_1_cc400_TCs.1D for sub-nyu0010089: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010089/func/sfnwmrda0010089_session_1_rest_2_cc400_TCs.1D for sub-nyu0010089: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010090/func/sfnwmrda0010090_session_1_rest_1_cc400_TCs.1D for sub-nyu0010090: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010090/func/sfnwmrda0010090_session_1_rest_2_cc400_TCs.1D for sub-nyu0010090: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010091/func/sfnwmrda0010091_session_1_rest_1_cc400_TCs.1D for sub-nyu0010091: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010091/func/sfnwmrda0010091_session_1_rest_2_cc400_TCs.1D for sub-nyu0010091: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010092/func/sfnwmrda0010092_session_1_rest_1_cc400_TCs.1D for sub-nyu0010092: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010092/func/sfnwmrda0010092_session_1_rest_2_cc400_TCs.1D for sub-nyu0010092: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010093/func/sfnwmrda0010093_session_1_rest_1_cc400_TCs.1D for sub-nyu0010093: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010093/func/sfnwmrda0010093_session_1_rest_2_cc400_TCs.1D for sub-nyu0010093: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010094/func/sfnwmrda0010094_session_1_rest_1_cc400_TCs.1D for sub-nyu0010094: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010094/func/sfnwmrda0010094_session_1_rest_2_cc400_TCs.1D for sub-nyu0010094: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010095/func/sfnwmrda0010095_session_1_rest_1_cc400_TCs.1D for sub-nyu0010095: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010095/func/sfnwmrda0010095_session_1_rest_2_cc400_TCs.1D for sub-nyu0010095: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010096/func/sfnwmrda0010096_session_1_rest_1_cc400_TCs.1D for sub-nyu0010096: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010096/func/sfnwmrda0010096_session_1_rest_2_cc400_TCs.1D for sub-nyu0010096: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010097/func/sfnwmrda0010097_session_1_rest_1_cc400_TCs.1D for sub-nyu0010097: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010097/func/sfnwmrda0010097_session_1_rest_2_cc400_TCs.1D for sub-nyu0010097: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010099/func/sfnwmrda0010099_session_1_rest_1_cc400_TCs.1D for sub-nyu0010099: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010099/func/sfnwmrda0010099_session_1_rest_2_cc400_TCs.1D for sub-nyu0010099: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010100/func/sfnwmrda0010100_session_1_rest_1_cc400_TCs.1D for sub-nyu0010100: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010100/func/sfnwmrda0010100_session_1_rest_2_cc400_TCs.1D for sub-nyu0010100: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010101/func/sfnwmrda0010101_session_1_rest_1_cc400_TCs.1D for sub-nyu0010101: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010101/func/sfnwmrda0010101_session_1_rest_2_cc400_TCs.1D for sub-nyu0010101: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010102/func/sfnwmrda0010102_session_1_rest_1_cc400_TCs.1D for sub-nyu0010102: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010102/func/sfnwmrda0010102_session_1_rest_2_cc400_TCs.1D for sub-nyu0010102: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010103/func/sfnwmrda0010103_session_1_rest_1_cc400_TCs.1D for sub-nyu0010103: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010104/func/sfnwmrda0010104_session_1_rest_1_cc400_TCs.1D for sub-nyu0010104: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010104/func/sfnwmrda0010104_session_1_rest_2_cc400_TCs.1D for sub-nyu0010104: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010106/func/sfnwmrda0010106_session_1_rest_1_cc400_TCs.1D for sub-nyu0010106: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010106/func/sfnwmrda0010106_session_1_rest_2_cc400_TCs.1D for sub-nyu0010106: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010107/func/sfnwmrda0010107_session_1_rest_1_cc400_TCs.1D for sub-nyu0010107: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010107/func/sfnwmrda0010107_session_1_rest_2_cc400_TCs.1D for sub-nyu0010107: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010108/func/sfnwmrda0010108_session_1_rest_1_cc400_TCs.1D for sub-nyu0010108: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010108/func/sfnwmrda0010108_session_1_rest_2_cc400_TCs.1D for sub-nyu0010108: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010109/func/sfnwmrda0010109_session_1_rest_1_cc400_TCs.1D for sub-nyu0010109: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010109/func/sfnwmrda0010109_session_1_rest_2_cc400_TCs.1D for sub-nyu0010109: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010110/func/sfnwmrda0010110_session_1_rest_1_cc400_TCs.1D for sub-nyu0010110: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010110/func/sfnwmrda0010110_session_1_rest_2_cc400_TCs.1D for sub-nyu0010110: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010111/func/sfnwmrda0010111_session_1_rest_1_cc400_TCs.1D for sub-nyu0010111: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010112/func/sfnwmrda0010112_session_1_rest_1_cc400_TCs.1D for sub-nyu0010112: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010112/func/sfnwmrda0010112_session_1_rest_2_cc400_TCs.1D for sub-nyu0010112: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010113/func/sfnwmrda0010113_session_1_rest_1_cc400_TCs.1D for sub-nyu0010113: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010113/func/sfnwmrda0010113_session_1_rest_2_cc400_TCs.1D for sub-nyu0010113: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010114/func/sfnwmrda0010114_session_1_rest_1_cc400_TCs.1D for sub-nyu0010114: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010114/func/sfnwmrda0010114_session_1_rest_2_cc400_TCs.1D for sub-nyu0010114: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010115/func/sfnwmrda0010115_session_1_rest_1_cc400_TCs.1D for sub-nyu0010115: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010115/func/sfnwmrda0010115_session_1_rest_2_cc400_TCs.1D for sub-nyu0010115: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010116/func/sfnwmrda0010116_session_1_rest_1_cc400_TCs.1D for sub-nyu0010116: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010116/func/sfnwmrda0010116_session_1_rest_2_cc400_TCs.1D for sub-nyu0010116: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010117/func/sfnwmrda0010117_session_1_rest_1_cc400_TCs.1D for sub-nyu0010117: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010117/func/sfnwmrda0010117_session_1_rest_2_cc400_TCs.1D for sub-nyu0010117: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010118/func/sfnwmrda0010118_session_1_rest_1_cc400_TCs.1D for sub-nyu0010118: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010118/func/sfnwmrda0010118_session_1_rest_2_cc400_TCs.1D for sub-nyu0010118: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010119/func/sfnwmrda0010119_session_1_rest_1_cc400_TCs.1D for sub-nyu0010119: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010120/func/sfnwmrda0010120_session_1_rest_1_cc400_TCs.1D for sub-nyu0010120: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010120/func/sfnwmrda0010120_session_1_rest_2_cc400_TCs.1D for sub-nyu0010120: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010121/func/sfnwmrda0010121_session_1_rest_1_cc400_TCs.1D for sub-nyu0010121: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010121/func/sfnwmrda0010121_session_1_rest_2_cc400_TCs.1D for sub-nyu0010121: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010122/func/sfnwmrda0010122_session_1_rest_1_cc400_TCs.1D for sub-nyu0010122: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010122/func/sfnwmrda0010122_session_1_rest_2_cc400_TCs.1D for sub-nyu0010122: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010123/func/sfnwmrda0010123_session_1_rest_1_cc400_TCs.1D for sub-nyu0010123: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010123/func/sfnwmrda0010123_session_1_rest_2_cc400_TCs.1D for sub-nyu0010123: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010124/func/sfnwmrda0010124_session_1_rest_1_cc400_TCs.1D for sub-nyu0010124: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010124/func/sfnwmrda0010124_session_1_rest_2_cc400_TCs.1D for sub-nyu0010124: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010125/func/sfnwmrda0010125_session_1_rest_1_cc400_TCs.1D for sub-nyu0010125: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010125/func/sfnwmrda0010125_session_1_rest_2_cc400_TCs.1D for sub-nyu0010125: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010126/func/sfnwmrda0010126_session_1_rest_1_cc400_TCs.1D for sub-nyu0010126: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010128/func/sfnwmrda0010128_session_1_rest_1_cc400_TCs.1D for sub-nyu0010128: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010129/func/sfnwmrda0010129_session_1_rest_1_cc400_TCs.1D for sub-nyu0010129: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu0010129/func/sfnwmrda0010129_session_1_rest_2_cc400_TCs.1D for sub-nyu0010129: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu1000804/func/sfnwmrda1000804_session_1_rest_1_cc400_TCs.1D for sub-nyu1000804: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu1000804/func/sfnwmrda1000804_session_1_rest_2_cc400_TCs.1D for sub-nyu1000804: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu1023964/func/sfnwmrda1023964_session_1_rest_1_cc400_TCs.1D for sub-nyu1023964: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu1023964/func/sfnwmrda1023964_session_1_rest_2_cc400_TCs.1D for sub-nyu1023964: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu1057962/func/sfnwmrda1057962_session_1_rest_1_cc400_TCs.1D for sub-nyu1057962: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu1099481/func/sfnwmrda1099481_session_1_rest_1_cc400_TCs.1D for sub-nyu1099481: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu1099481/func/sfnwmrda1099481_session_1_rest_2_cc400_TCs.1D for sub-nyu1099481: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu1127915/func/sfnwmrda1127915_session_1_rest_1_cc400_TCs.1D for sub-nyu1127915: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu1127915/func/sfnwmrda1127915_session_1_rest_2_cc400_TCs.1D for sub-nyu1127915: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu1187766/func/sfnwmrda1187766_session_1_rest_1_cc400_TCs.1D for sub-nyu1187766: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu1187766/func/sfnwmrda1187766_session_1_rest_2_cc400_TCs.1D for sub-nyu1187766: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu1208795/func/sfnwmrda1208795_session_1_rest_1_cc400_TCs.1D for sub-nyu1208795: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu1208795/func/sfnwmrda1208795_session_1_rest_2_cc400_TCs.1D for sub-nyu1208795: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu1283494/func/sfnwmrda1283494_session_1_rest_1_cc400_TCs.1D for sub-nyu1283494: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu1320247/func/sfnwmrda1320247_session_1_rest_1_cc400_TCs.1D for sub-nyu1320247: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu1320247/func/sfnwmrda1320247_session_1_rest_2_cc400_TCs.1D for sub-nyu1320247: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu1359325/func/sfnwmrda1359325_session_1_rest_1_cc400_TCs.1D for sub-nyu1359325: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu1359325/func/sfnwmrda1359325_session_1_rest_2_cc400_TCs.1D for sub-nyu1359325: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu1435954/func/sfnwmrda1435954_session_1_rest_1_cc400_TCs.1D for sub-nyu1435954: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu1435954/func/sfnwmrda1435954_session_1_rest_2_cc400_TCs.1D for sub-nyu1435954: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu1471736/func/sfnwmrda1471736_session_1_rest_1_cc400_TCs.1D for sub-nyu1471736: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu1471736/func/sfnwmrda1471736_session_1_rest_2_cc400_TCs.1D for sub-nyu1471736: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu1497055/func/sfnwmrda1497055_session_1_rest_1_cc400_TCs.1D for sub-nyu1497055: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu1497055/func/sfnwmrda1497055_session_1_rest_2_cc400_TCs.1D for sub-nyu1497055: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu1511464/func/sfnwmrda1511464_session_1_rest_1_cc400_TCs.1D for sub-nyu1511464: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu1511464/func/sfnwmrda1511464_session_1_rest_2_cc400_TCs.1D for sub-nyu1511464: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu1517240/func/sfnwmrda1517240_session_1_rest_1_cc400_TCs.1D for sub-nyu1517240: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu1567356/func/sfnwmrda1567356_session_1_rest_1_cc400_TCs.1D for sub-nyu1567356: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu1567356/func/sfnwmrda1567356_session_1_rest_2_cc400_TCs.1D for sub-nyu1567356: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu1700637/func/sfnwmrda1700637_session_1_rest_1_cc400_TCs.1D for sub-nyu1700637: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu1700637/func/sfnwmrda1700637_session_1_rest_2_cc400_TCs.1D for sub-nyu1700637: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu1737393/func/sfnwmrda1737393_session_1_rest_1_cc400_TCs.1D for sub-nyu1737393: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu1737393/func/sfnwmrda1737393_session_1_rest_2_cc400_TCs.1D for sub-nyu1737393: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu1740607/func/sfnwmrda1740607_session_1_rest_1_cc400_TCs.1D for sub-nyu1740607: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu1740607/func/sfnwmrda1740607_session_1_rest_2_cc400_TCs.1D for sub-nyu1740607: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu1780174/func/sfnwmrda1780174_session_1_rest_1_cc400_TCs.1D for sub-nyu1780174: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu1780174/func/sfnwmrda1780174_session_1_rest_2_cc400_TCs.1D for sub-nyu1780174: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu1854959/func/sfnwmrda1854959_session_1_rest_1_cc400_TCs.1D for sub-nyu1854959: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu1854959/func/sfnwmrda1854959_session_1_rest_2_cc400_TCs.1D for sub-nyu1854959: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu1875084/func/sfnwmrda1875084_session_1_rest_1_cc400_TCs.1D for sub-nyu1875084: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu1884448/func/sfnwmrda1884448_session_1_rest_1_cc400_TCs.1D for sub-nyu1884448: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu1884448/func/sfnwmrda1884448_session_1_rest_2_cc400_TCs.1D for sub-nyu1884448: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu1918630/func/sfnwmrda1918630_session_1_rest_1_cc400_TCs.1D for sub-nyu1918630: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu1918630/func/sfnwmrda1918630_session_1_rest_2_cc400_TCs.1D for sub-nyu1918630: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu1934623/func/sfnwmrda1934623_session_1_rest_1_cc400_TCs.1D for sub-nyu1934623: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu1934623/func/sfnwmrda1934623_session_1_rest_2_cc400_TCs.1D for sub-nyu1934623: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu1992284/func/sfnwmrda1992284_session_1_rest_1_cc400_TCs.1D for sub-nyu1992284: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu1992284/func/sfnwmrda1992284_session_1_rest_2_cc400_TCs.1D for sub-nyu1992284: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu1995121/func/sfnwmrda1995121_session_1_rest_1_cc400_TCs.1D for sub-nyu1995121: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu2030383/func/sfnwmrda2030383_session_1_rest_1_cc400_TCs.1D for sub-nyu2030383: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu2030383/func/sfnwmrda2030383_session_1_rest_2_cc400_TCs.1D for sub-nyu2030383: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu2054438/func/sfnwmrda2054438_session_1_rest_1_cc400_TCs.1D for sub-nyu2054438: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu2054438/func/sfnwmrda2054438_session_1_rest_2_cc400_TCs.1D for sub-nyu2054438: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu2107638/func/sfnwmrda2107638_session_1_rest_1_cc400_TCs.1D for sub-nyu2107638: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu2107638/func/sfnwmrda2107638_session_1_rest_2_cc400_TCs.1D for sub-nyu2107638: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu2136051/func/sfnwmrda2136051_session_1_rest_1_cc400_TCs.1D for sub-nyu2136051: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu2136051/func/sfnwmrda2136051_session_1_rest_2_cc400_TCs.1D for sub-nyu2136051: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu2230510/func/sfnwmrda2230510_session_1_rest_1_cc400_TCs.1D for sub-nyu2230510: T=173, R=353, TR=None
# Processing Athena_flat/sub-nyu2230510/func/sfnwmrda2230510_session_1_rest_2_cc400_TCs.1D for sub-nyu2230510: T=173, R=353, TR=None
# ...
# Processing Athena_flat/sub-washu0015024/func/sfnwmrda0015024_session_1_rest_1_cc400_TCs.1D for sub-washu0015024: T=129, R=353, TR=None
# Processing Athena_flat/sub-washu0015025/func/sfnwmrda0015025_session_1_rest_1_cc400_TCs.1D for sub-washu0015025: T=129, R=353, TR=None
# Processing Athena_flat/sub-washu0015026/func/sfnwmrda0015026_session_3_rest_1_cc400_TCs.1D for sub-washu0015026: T=129, R=353, TR=None
# Processing Athena_flat/sub-washu0015026/func/sfnwmrda0015026_session_3_rest_2_cc400_TCs.1D for sub-washu0015026: T=129, R=353, TR=None
# Processing Athena_flat/sub-washu0015026/func/sfnwmrda0015026_session_3_rest_3_cc400_TCs.1D for sub-washu0015026: T=129, R=353, TR=None
# Processing Athena_flat/sub-washu0015027/func/sfnwmrda0015027_session_2_rest_1_cc400_TCs.1D for sub-washu0015027: T=129, R=353, TR=None
# Processing Athena_flat/sub-washu0015027/func/sfnwmrda0015027_session_2_rest_2_cc400_TCs.1D for sub-washu0015027: T=129, R=353, TR=None
# Processing Athena_flat/sub-washu0015027/func/sfnwmrda0015027_session_2_rest_3_cc400_TCs.1D for sub-washu0015027: T=129, R=353, TR=None
# Processing Athena_flat/sub-washu0015028/func/sfnwmrda0015028_session_1_rest_1_cc400_TCs.1D for sub-washu0015028: T=129, R=353, TR=None
# Processing Athena_flat/sub-washu0015028/func/sfnwmrda0015028_session_1_rest_2_cc400_TCs.1D for sub-washu0015028: T=129, R=353, TR=None
# Processing Athena_flat/sub-washu0015028/func/sfnwmrda0015028_session_1_rest_3_cc400_TCs.1D for sub-washu0015028: T=129, R=353, TR=None
# Processing Athena_flat/sub-washu0015029/func/sfnwmrda0015029_session_1_rest_1_cc400_TCs.1D for sub-washu0015029: T=129, R=353, TR=None
# Processing Athena_flat/sub-washu0015029/func/sfnwmrda0015029_session_1_rest_2_cc400_TCs.1D for sub-washu0015029: T=129, R=353, TR=None
# Processing Athena_flat/sub-washu0015029/func/sfnwmrda0015029_session_1_rest_3_cc400_TCs.1D for sub-washu0015029: T=129, R=353, TR=None
# Processing Athena_flat/sub-washu0015030/func/sfnwmrda0015030_session_1_rest_1_cc400_TCs.1D for sub-washu0015030: T=129, R=353, TR=None
# Processing Athena_flat/sub-washu0015030/func/sfnwmrda0015030_session_1_rest_2_cc400_TCs.1D for sub-washu0015030: T=129, R=353, TR=None
# Processing Athena_flat/sub-washu0015030/func/sfnwmrda0015030_session_1_rest_3_cc400_TCs.1D for sub-washu0015030: T=129, R=353, TR=None
# Processing Athena_flat/sub-washu0015031/func/sfnwmrda0015031_session_1_rest_1_cc400_TCs.1D for sub-washu0015031: T=129, R=353, TR=None
# Processing Athena_flat/sub-washu0015031/func/sfnwmrda0015031_session_1_rest_2_cc400_TCs.1D for sub-washu0015031: T=129, R=353, TR=None
# Processing Athena_flat/sub-washu0015031/func/sfnwmrda0015031_session_1_rest_3_cc400_TCs.1D for sub-washu0015031: T=129, R=353, TR=None
# Processing Athena_flat/sub-washu0015032/func/sfnwmrda0015032_session_2_rest_1_cc400_TCs.1D for sub-washu0015032: T=129, R=353, TR=None
# Processing Athena_flat/sub-washu0015032/func/sfnwmrda0015032_session_2_rest_2_cc400_TCs.1D for sub-washu0015032: T=129, R=353, TR=None
# Processing Athena_flat/sub-washu0015032/func/sfnwmrda0015032_session_2_rest_3_cc400_TCs.1D for sub-washu0015032: T=129, R=353, TR=None
# Processing Athena_flat/sub-washu0015033/func/sfnwmrda0015033_session_1_rest_1_cc400_TCs.1D for sub-washu0015033: T=129, R=353, TR=None
# Processing Athena_flat/sub-washu0015033/func/sfnwmrda0015033_session_1_rest_2_cc400_TCs.1D for sub-washu0015033: T=129, R=353, TR=None
# Processing Athena_flat/sub-washu0015033/func/sfnwmrda0015033_session_1_rest_3_cc400_TCs.1D for sub-washu0015033: T=129, R=353, TR=None
# Processing Athena_flat/sub-washu0015034/func/sfnwmrda0015034_session_1_rest_1_cc400_TCs.1D for sub-washu0015034: T=129, R=353, TR=None
# Processing Athena_flat/sub-washu0015034/func/sfnwmrda0015034_session_1_rest_2_cc400_TCs.1D for sub-washu0015034: T=129, R=353, TR=None
# Processing Athena_flat/sub-washu0015034/func/sfnwmrda0015034_session_1_rest_3_cc400_TCs.1D for sub-washu0015034: T=129, R=353, TR=None
# Processing Athena_flat/sub-washu0015035/func/sfnwmrda0015035_session_1_rest_1_cc400_TCs.1D for sub-washu0015035: T=129, R=353, TR=None
# Processing Athena_flat/sub-washu0015035/func/sfnwmrda0015035_session_1_rest_2_cc400_TCs.1D for sub-washu0015035: T=129, R=353, TR=None
# Processing Athena_flat/sub-washu0015035/func/sfnwmrda0015035_session_1_rest_3_cc400_TCs.1D for sub-washu0015035: T=129, R=353, TR=None
# Processing Athena_flat/sub-washu0015036/func/sfnwmrda0015036_session_2_rest_1_cc400_TCs.1D for sub-washu0015036: T=129, R=353, TR=None
# Processing Athena_flat/sub-washu0015036/func/sfnwmrda0015036_session_2_rest_2_cc400_TCs.1D for sub-washu0015036: T=129, R=353, TR=None
# Processing Athena_flat/sub-washu0015036/func/sfnwmrda0015036_session_2_rest_3_cc400_TCs.1D for sub-washu0015036: T=129, R=353, TR=None
# Processing Athena_flat/sub-washu0015037/func/sfnwmrda0015037_session_1_rest_1_cc400_TCs.1D for sub-washu0015037: T=129, R=353, TR=None
# Processing Athena_flat/sub-washu0015037/func/sfnwmrda0015037_session_1_rest_2_cc400_TCs.1D for sub-washu0015037: T=129, R=353, TR=None
# Processing Athena_flat/sub-washu0015037/func/sfnwmrda0015037_session_1_rest_3_cc400_TCs.1D for sub-washu0015037: T=129, R=353, TR=None
# Processing Athena_flat/sub-washu0015038/func/sfnwmrda0015038_session_1_rest_1_cc400_TCs.1D for sub-washu0015038: T=129, R=353, TR=None
# Processing Athena_flat/sub-washu0015039/func/sfnwmrda0015039_session_1_rest_1_cc400_TCs.1D for sub-washu0015039: T=129, R=353, TR=None
# Processing Athena_flat/sub-washu0015039/func/sfnwmrda0015039_session_1_rest_2_cc400_TCs.1D for sub-washu0015039: T=129, R=353, TR=None
# Processing Athena_flat/sub-washu0015039/func/sfnwmrda0015039_session_1_rest_3_cc400_TCs.1D for sub-washu0015039: T=129, R=353, TR=None
# Processing Athena_flat/sub-washu0015040/func/sfnwmrda0015040_session_1_rest_1_cc400_TCs.1D for sub-washu0015040: T=129, R=353, TR=None
# Processing Athena_flat/sub-washu0015040/func/sfnwmrda0015040_session_1_rest_2_cc400_TCs.1D for sub-washu0015040: T=129, R=353, TR=None
# Processing Athena_flat/sub-washu0015040/func/sfnwmrda0015040_session_1_rest_3_cc400_TCs.1D for sub-washu0015040: T=129, R=353, TR=None
# Processing Athena_flat/sub-washu0015041/func/sfnwmrda0015041_session_1_rest_1_cc400_TCs.1D for sub-washu0015041: T=129, R=353, TR=None
# Processing Athena_flat/sub-washu0015041/func/sfnwmrda0015041_session_1_rest_2_cc400_TCs.1D for sub-washu0015041: T=129, R=353, TR=None
# Processing Athena_flat/sub-washu0015041/func/sfnwmrda0015041_session_1_rest_3_cc400_TCs.1D for sub-washu0015041: T=129, R=353, TR=None
# Processing Athena_flat/sub-washu0015042/func/sfnwmrda0015042_session_1_rest_1_cc400_TCs.1D for sub-washu0015042: T=129, R=353, TR=None
# Processing Athena_flat/sub-washu0015042/func/sfnwmrda0015042_session_1_rest_2_cc400_TCs.1D for sub-washu0015042: T=129, R=353, TR=None
# Processing Athena_flat/sub-washu0015042/func/sfnwmrda0015042_session_1_rest_3_cc400_TCs.1D for sub-washu0015042: T=129, R=353, TR=None
# Processing Athena_flat/sub-washu0015043/func/sfnwmrda0015043_session_1_rest_1_cc400_TCs.1D for sub-washu0015043: T=129, R=353, TR=None
# Processing Athena_flat/sub-washu0015043/func/sfnwmrda0015043_session_1_rest_2_cc400_TCs.1D for sub-washu0015043: T=129, R=353, TR=None
# Processing Athena_flat/sub-washu0015043/func/sfnwmrda0015043_session_1_rest_3_cc400_TCs.1D for sub-washu0015043: T=129, R=353, TR=None
# Processing Athena_flat/sub-washu0015044/func/sfnwmrda0015044_session_1_rest_1_cc400_TCs.1D for sub-washu0015044: T=129, R=353, TR=None
# Processing Athena_flat/sub-washu0015044/func/sfnwmrda0015044_session_1_rest_2_cc400_TCs.1D for sub-washu0015044: T=129, R=353, TR=None
# Processing Athena_flat/sub-washu0015044/func/sfnwmrda0015044_session_1_rest_3_cc400_TCs.1D for sub-washu0015044: T=129, R=353, TR=None
# Processing Athena_flat/sub-washu0015045/func/sfnwmrda0015045_session_1_rest_1_cc400_TCs.1D for sub-washu0015045: T=129, R=353, TR=None
# Processing Athena_flat/sub-washu0015045/func/sfnwmrda0015045_session_1_rest_2_cc400_TCs.1D for sub-washu0015045: T=129, R=353, TR=None
# Processing Athena_flat/sub-washu0015045/func/sfnwmrda0015045_session_1_rest_3_cc400_TCs.1D for sub-washu0015045: T=129, R=353, TR=None
# Processing Athena_flat/sub-washu0015046/func/sfnwmrda0015046_session_1_rest_1_cc400_TCs.1D for sub-washu0015046: T=129, R=353, TR=None
# Processing Athena_flat/sub-washu0015046/func/sfnwmrda0015046_session_1_rest_2_cc400_TCs.1D for sub-washu0015046: T=129, R=353, TR=None
# Processing Athena_flat/sub-washu0015047/func/sfnwmrda0015047_session_1_rest_1_cc400_TCs.1D for sub-washu0015047: T=129, R=353, TR=None
# Processing Athena_flat/sub-washu0015047/func/sfnwmrda0015047_session_1_rest_2_cc400_TCs.1D for sub-washu0015047: T=129, R=353, TR=None
# Processing Athena_flat/sub-washu0015047/func/sfnwmrda0015047_session_1_rest_3_cc400_TCs.1D for sub-washu0015047: T=129, R=353, TR=None
# Processing Athena_flat/sub-washu0015048/func/sfnwmrda0015048_session_1_rest_1_cc400_TCs.1D for sub-washu0015048: T=129, R=353, TR=None
# Processing Athena_flat/sub-washu0015048/func/sfnwmrda0015048_session_1_rest_2_cc400_TCs.1D for sub-washu0015048: T=129, R=353, TR=None
# Processing Athena_flat/sub-washu0015048/func/sfnwmrda0015048_session_1_rest_3_cc400_TCs.1D for sub-washu0015048: T=129, R=353, TR=None
# Processing Athena_flat/sub-washu0015049/func/sfnwmrda0015049_session_1_rest_1_cc400_TCs.1D for sub-washu0015049: T=129, R=353, TR=None
# Processing Athena_flat/sub-washu0015049/func/sfnwmrda0015049_session_1_rest_2_cc400_TCs.1D for sub-washu0015049: T=129, R=353, TR=None
# Processing Athena_flat/sub-washu0015049/func/sfnwmrda0015049_session_1_rest_3_cc400_TCs.1D for sub-washu0015049: T=129, R=353, TR=None
# Processing Athena_flat/sub-washu0015050/func/sfnwmrda0015050_session_1_rest_1_cc400_TCs.1D for sub-washu0015050: T=129, R=353, TR=None
# Processing Athena_flat/sub-washu0015050/func/sfnwmrda0015050_session_1_rest_2_cc400_TCs.1D for sub-washu0015050: T=129, R=353, TR=None
# Processing Athena_flat/sub-washu0015050/func/sfnwmrda0015050_session_1_rest_3_cc400_TCs.1D for sub-washu0015050: T=129, R=353, TR=None
# Processing Athena_flat/sub-washu0015051/func/sfnwmrda0015051_session_1_rest_1_cc400_TCs.1D for sub-washu0015051: T=129, R=353, TR=None
# Processing Athena_flat/sub-washu0015051/func/sfnwmrda0015051_session_1_rest_2_cc400_TCs.1D for sub-washu0015051: T=129, R=353, TR=None
# Processing Athena_flat/sub-washu0015052/func/sfnwmrda0015052_session_2_rest_1_cc400_TCs.1D for sub-washu0015052: T=129, R=353, TR=None
# Processing Athena_flat/sub-washu0015052/func/sfnwmrda0015052_session_2_rest_2_cc400_TCs.1D for sub-washu0015052: T=129, R=353, TR=None
# Processing Athena_flat/sub-washu0015052/func/sfnwmrda0015052_session_2_rest_3_cc400_TCs.1D for sub-washu0015052: T=129, R=353, TR=None
# Processing Athena_flat/sub-washu0015053/func/sfnwmrda0015053_session_1_rest_1_cc400_TCs.1D for sub-washu0015053: T=129, R=353, TR=None
# Processing Athena_flat/sub-washu0015053/func/sfnwmrda0015053_session_1_rest_2_cc400_TCs.1D for sub-washu0015053: T=129, R=353, TR=None
# Processing Athena_flat/sub-washu0015053/func/sfnwmrda0015053_session_1_rest_3_cc400_TCs.1D for sub-washu0015053: T=129, R=353, TR=None
# Processing Athena_flat/sub-washu0015054/func/sfnwmrda0015054_session_1_rest_1_cc400_TCs.1D for sub-washu0015054: T=129, R=353, TR=None
# Processing Athena_flat/sub-washu0015054/func/sfnwmrda0015054_session_1_rest_2_cc400_TCs.1D for sub-washu0015054: T=129, R=353, TR=None
# Processing Athena_flat/sub-washu0015054/func/sfnwmrda0015054_session_1_rest_3_cc400_TCs.1D for sub-washu0015054: T=129, R=353, TR=None
# Processing Athena_flat/sub-washu0015055/func/sfnwmrda0015055_session_1_rest_1_cc400_TCs.1D for sub-washu0015055: T=129, R=353, TR=None
# Processing Athena_flat/sub-washu0015055/func/sfnwmrda0015055_session_1_rest_2_cc400_TCs.1D for sub-washu0015055: T=129, R=353, TR=None
# Processing Athena_flat/sub-washu0015056/func/sfnwmrda0015056_session_1_rest_1_cc400_TCs.1D for sub-washu0015056: T=129, R=353, TR=None
# Processing Athena_flat/sub-washu0015056/func/sfnwmrda0015056_session_1_rest_2_cc400_TCs.1D for sub-washu0015056: T=129, R=353, TR=None
# Processing Athena_flat/sub-washu0015057/func/sfnwmrda0015057_session_2_rest_1_cc400_TCs.1D for sub-washu0015057: T=129, R=353, TR=None
# Processing Athena_flat/sub-washu0015057/func/sfnwmrda0015057_session_2_rest_2_cc400_TCs.1D for sub-washu0015057: T=129, R=353, TR=None
# Processing Athena_flat/sub-washu0015057/func/sfnwmrda0015057_session_2_rest_3_cc400_TCs.1D for sub-washu0015057: T=129, R=353, TR=None
# Processing Athena_flat/sub-washu0015058/func/sfnwmrda0015058_session_1_rest_1_cc400_TCs.1D for sub-washu0015058: T=129, R=353, TR=None
# Processing Athena_flat/sub-washu0015058/func/sfnwmrda0015058_session_1_rest_2_cc400_TCs.1D for sub-washu0015058: T=129, R=353, TR=None
# Processing Athena_flat/sub-washu0015058/func/sfnwmrda0015058_session_1_rest_3_cc400_TCs.1D for sub-washu0015058: T=129, R=353, TR=None
# Processing Athena_flat/sub-washu0015059/func/sfnwmrda0015059_session_1_rest_1_cc400_TCs.1D for sub-washu0015059: T=129, R=353, TR=None
# Processing Athena_flat/sub-washu0015059/func/sfnwmrda0015059_session_1_rest_2_cc400_TCs.1D for sub-washu0015059: T=129, R=353, TR=None
# Processing Athena_flat/sub-washu0015059/func/sfnwmrda0015059_session_1_rest_3_cc400_TCs.1D for sub-washu0015059: T=129, R=353, TR=None
# Processing Athena_flat/sub-washu0015060/func/sfnwmrda0015060_session_1_rest_1_cc400_TCs.1D for sub-washu0015060: T=129, R=353, TR=None
# Processing Athena_flat/sub-washu0015060/func/sfnwmrda0015060_session_1_rest_2_cc400_TCs.1D for sub-washu0015060: T=129, R=353, TR=None
# Processing Athena_flat/sub-washu0015060/func/sfnwmrda0015060_session_1_rest_3_cc400_TCs.1D for sub-washu0015060: T=129, R=353, TR=None
# Processing Athena_flat/sub-washu0015061/func/sfnwmrda0015061_session_1_rest_1_cc400_TCs.1D for sub-washu0015061: T=129, R=353, TR=None
# Processing Athena_flat/sub-washu0015061/func/sfnwmrda0015061_session_1_rest_2_cc400_TCs.1D for sub-washu0015061: T=129, R=353, TR=None
# Processing Athena_flat/sub-washu0015061/func/sfnwmrda0015061_session_1_rest_3_cc400_TCs.1D for sub-washu0015061: T=129, R=353, TR=None
# Processing Athena_flat/sub-washu0015062/func/sfnwmrda0015062_session_1_rest_1_cc400_TCs.1D for sub-washu0015062: T=129, R=353, TR=None
# Processing Athena_flat/sub-washu0015062/func/sfnwmrda0015062_session_1_rest_2_cc400_TCs.1D for sub-washu0015062: T=129, R=353, TR=None
# Processing Athena_flat/sub-washu0015062/func/sfnwmrda0015062_session_1_rest_3_cc400_TCs.1D for sub-washu0015062: T=129, R=353, TR=None
# Сохранён manifest: Athena_flat/manifest.csv
#    participant_id                                               file  \
# 0  sub-kki1018959  Athena_flat/sub-kki1018959/func/sfnwmrda101895...
# 1  sub-kki1019436  Athena_flat/sub-kki1019436/func/sfnwmrda101943...
# 2  sub-kki1043241  Athena_flat/sub-kki1043241/func/sfnwmrda104324...
# 3  sub-kki1266183  Athena_flat/sub-kki1266183/func/sfnwmrda126618...
# 4  sub-kki1535233  Athena_flat/sub-kki1535233/func/sfnwmrda153523...
#
#                                             tsv_path  \
# 0  Athena_flat/sub-kki1018959/func/sfnwmrda101895...
# 1  Athena_flat/sub-kki1019436/func/sfnwmrda101943...
# 2  Athena_flat/sub-kki1043241/func/sfnwmrda104324...
# 3  Athena_flat/sub-kki1266183/func/sfnwmrda126618...
# 4  Athena_flat/sub-kki1535233/func/sfnwmrda153523...
#
#                                             npy_path    T    R filter_version  \
# 0  Athena_flat/sub-kki1018959/func/sfnwmrda101895...  148  351       filtered
# 1  Athena_flat/sub-kki1019436/func/sfnwmrda101943...  148  351       filtered
# 2  Athena_flat/sub-kki1043241/func/sfnwmrda104324...  148  351       filtered
# 3  Athena_flat/sub-kki1266183/func/sfnwmrda126618...  120  351       filtered
# 4  Athena_flat/sub-kki1535233/func/sfnwmrda153523...  148  351       filtered
#
#      TR bold_json
# 0  None
# 1  None
# 2  None
# 3  None
# 4  None
# Всего рядов: 1198

# %% [markdown]
# ## 2.1 Валидация TR и длительностей

# %%
manifest = pd.read_csv(DEST_ROOT/"manifest.csv")
manifest['has_TR'] = manifest['TR'].notna()
manifest['duration_sec'] = np.where(manifest['has_TR'], manifest['T']*manifest['TR'], np.nan)
manifest['too_short'] = manifest['T'] < MIN_VOLS_TR
display(manifest[['participant_id','file','T','R','TR','duration_sec','filter_version','too_short']].head(20))
print('TR coverage:', manifest['has_TR'].mean())
print('Коротких:', manifest['too_short'].sum(), 'из', len(manifest))
manifest.to_csv(DEST_ROOT/"manifest.csv", index=False)
# Out:
#     participant_id                                               file    T  \
# 0   sub-kki1018959  Athena_flat/sub-kki1018959/func/sfnwmrda101895...  148
# 1   sub-kki1019436  Athena_flat/sub-kki1019436/func/sfnwmrda101943...  148
# 2   sub-kki1043241  Athena_flat/sub-kki1043241/func/sfnwmrda104324...  148
# 3   sub-kki1266183  Athena_flat/sub-kki1266183/func/sfnwmrda126618...  120
# 4   sub-kki1535233  Athena_flat/sub-kki1535233/func/sfnwmrda153523...  148
# 5   sub-kki1541812  Athena_flat/sub-kki1541812/func/sfnwmrda154181...  120
# 6   sub-kki1577042  Athena_flat/sub-kki1577042/func/sfnwmrda157704...  120
# 7   sub-kki1594156  Athena_flat/sub-kki1594156/func/sfnwmrda159415...  120
# 8   sub-kki1623716  Athena_flat/sub-kki1623716/func/sfnwmrda162371...  120
# 9   sub-kki1638334  Athena_flat/sub-kki1638334/func/sfnwmrda163833...  120
# 10  sub-kki1652369  Athena_flat/sub-kki1652369/func/sfnwmrda165236...  120
# 11  sub-kki1686265  Athena_flat/sub-kki1686265/func/sfnwmrda168626...  120
# 12  sub-kki1692275  Athena_flat/sub-kki1692275/func/sfnwmrda169227...  120
# 13  sub-kki1735881  Athena_flat/sub-kki1735881/func/sfnwmrda173588...  120
# 14  sub-kki1779922  Athena_flat/sub-kki1779922/func/sfnwmrda177992...  148
# 15  sub-kki1842819  Athena_flat/sub-kki1842819/func/sfnwmrda184281...  120
# 16  sub-kki1846346  Athena_flat/sub-kki1846346/func/sfnwmrda184634...  148
# 17  sub-kki1873761  Athena_flat/sub-kki1873761/func/sfnwmrda187376...  120
# 18  sub-kki1962503  Athena_flat/sub-kki1962503/func/sfnwmrda196250...  120
# 19  sub-kki1988015  Athena_flat/sub-kki1988015/func/sfnwmrda198801...  148
#
#       R  TR  duration_sec filter_version  too_short
# 0   351 NaN           NaN       filtered      False
# 1   351 NaN           NaN       filtered      False
# 2   351 NaN           NaN       filtered      False
# 3   351 NaN           NaN       filtered      False
# 4   351 NaN           NaN       filtered      False
# 5   351 NaN           NaN       filtered      False
# 6   351 NaN           NaN       filtered      False
# 7   351 NaN           NaN       filtered      False
# 8   351 NaN           NaN       filtered      False
# 9   351 NaN           NaN       filtered      False
# 10  351 NaN           NaN       filtered      False
# 11  351 NaN           NaN       filtered      False
# 12  351 NaN           NaN       filtered      False
# 13  351 NaN           NaN       filtered      False
# 14  351 NaN           NaN       filtered      False
# 15  351 NaN           NaN       filtered      False
# 16  351 NaN           NaN       filtered      False
# 17  351 NaN           NaN       filtered      False
# 18  351 NaN           NaN       filtered      False
# 19  351 NaN           NaN       filtered      False
# TR coverage: 0.0
# Коротких: 1 из 1198

# %% [markdown]
# ## 2.2 Агрегирование прогонов (per-subject)
#
# Если у субъекта несколько прогонов, агрегируем их в один файл NPY и TSV, а также обновляем манифест.

# %%
man = pd.read_csv(DEST_ROOT/"manifest.csv")
groups = man.groupby('participant_id')
agg_rows = []; agg_dir = DEST_ROOT/"aggregated"; agg_dir.mkdir(parents=True, exist_ok=True)

def pad_to(X, Tfinal):
    T,R = X.shape
    if T >= Tfinal: return X[:Tfinal]
    Y = np.zeros((Tfinal,R), dtype=X.dtype); Y[:T]=X; return Y

for pid, df in groups:
    npys = df['npy_path'].tolist()
    if not npys: continue
    mats = [np.load(p) for p in npys]
    if AGGREGATE_MODE=='concat':
        cat = np.concatenate(mats, axis=0)
        Tfinal = WIN_TR_AGG if WIN_TR_AGG>0 else cat.shape[0]
        Xagg = pad_to(cat, Tfinal)
    elif AGGREGATE_MODE=='mean':
        Tmax = max(m.shape[0] for m in mats)
        mats_eq = [pad_to(m, Tmax) for m in mats]
        Xagg = np.mean(mats_eq, axis=0)
        if WIN_TR_AGG>0: Xagg = pad_to(Xagg, WIN_TR_AGG)
    else:
        Xagg = mats[0]
        if WIN_TR_AGG>0: Xagg = pad_to(Xagg, WIN_TR_AGG)
    out_path = agg_dir / f"{pid}_agg_{AGGREGATE_MODE}_{WIN_TR_AGG if WIN_TR_AGG>0 else 'var'}tr.npy"
    np.save(out_path, Xagg)
    TRs = df['TR'].dropna().values
    tr_val = float(np.mean(TRs)) if TRs.size>0 else np.nan
    agg_rows.append({"participant_id": pid, "n_runs": len(npys), "R": int(Xagg.shape[1]), "TR": tr_val, "npy_path": str(out_path)})

agg_manifest = pd.DataFrame(agg_rows)
agg_manifest.to_csv(DEST_ROOT/"aggregate_manifest.csv", index=False)
print('Сохранён aggregate_manifest:', DEST_ROOT/"aggregate_manifest.csv")
display(agg_manifest.head())
# Out:
# Сохранён aggregate_manifest: Athena_flat/aggregate_manifest.csv
#    participant_id  n_runs    R  TR  \
# 0  sub-kki1018959       1  351 NaN
# 1  sub-kki1019436       1  351 NaN
# 2  sub-kki1043241       1  351 NaN
# 3  sub-kki1266183       1  351 NaN
# 4  sub-kki1535233       1  351 NaN
#
#                                             npy_path
# 0  Athena_flat/aggregated/sub-kki1018959_agg_conc...
# 1  Athena_flat/aggregated/sub-kki1019436_agg_conc...
# 2  Athena_flat/aggregated/sub-kki1043241_agg_conc...
# 3  Athena_flat/aggregated/sub-kki1266183_agg_conc...
# 4  Athena_flat/aggregated/sub-kki1535233_agg_conc...

# %% [markdown]
# ## 2.3 Фильтрация испытуемых на основании .csv списка
#
# Здесь мы можем отфильтровать испытуемых на основании внешнего списка по возрастным когортам.

# %%
DESIRED_TRIALS_LIST_FILE_TEENS = "./cohort_teen_participants.txt"
FILTERED_DEST_ROOT_TEENS = "./Athena_flat_filtered/cohort_teen_participants"

DESIRED_TRIALS_LIST_FILE_ADULTS = "./cohort_adult_participants.txt"
FILTERED_DEST_ROOT_ADULTS = "./Athena_flat_filtered/cohort_adult_participants"

# Создаем директорию для отфильтрованных данных подростков
shutil.rmtree(FILTERED_DEST_ROOT_TEENS, ignore_errors=True)
os.makedirs(FILTERED_DEST_ROOT_TEENS, exist_ok=True)

# Читаем желаемый список субъектов из .txt файла построчно
with open(DESIRED_TRIALS_LIST_FILE_TEENS, 'r') as f:
    desired_teen_ids = set(line.strip() for line in f if line.strip())
# Добавим префикс 'sub-' к каждому идентификатору, если его нет
desired_teen_ids = set(pid if pid.startswith('sub-') else f'sub-{pid}' for pid in desired_teen_ids)
print("Желаемых субъектов (teen participants):", len(desired_teen_ids))

# Создаем директорию для отфильтрованных данных взрослых
shutil.rmtree(FILTERED_DEST_ROOT_ADULTS, ignore_errors=True)
os.makedirs(FILTERED_DEST_ROOT_ADULTS, exist_ok=True)

# Читаем желаемый список субъектов из .txt файла построчно
with open(DESIRED_TRIALS_LIST_FILE_ADULTS, 'r') as f:
    desired_adult_ids = set(line.strip() for line in f if line.strip())
# Добавим префикс 'sub-' к каждому идентификатору, если его нет
desired_adult_ids = set(pid if pid.startswith('sub-') else f'sub-{pid}' for pid in desired_adult_ids)
print("Желаемых субъектов (adult participants):", len(desired_adult_ids))
# Out:
# Желаемых субъектов (teen participants): 274
# Желаемых субъектов (adult participants): 117

# %%
original_manifest = pd.read_csv(DEST_ROOT/"manifest.csv")

# Скопируем соответствующие данные подростков по списку
filtered_manifest_teen = original_manifest[original_manifest['participant_id'].isin(desired_teen_ids)]
filtered_manifest_teen.to_csv(Path(FILTERED_DEST_ROOT_TEENS) / "manifest.csv", index=False)
print("Сохранён отфильтрованный manifest для подростков:", Path(FILTERED_DEST_ROOT_TEENS) / "manifest.csv")

# Скопируем соответствующие данные взрослых по списку
filtered_manifest_adult = original_manifest[original_manifest['participant_id'].isin(desired_adult_ids)]
filtered_manifest_adult.to_csv(Path(FILTERED_DEST_ROOT_ADULTS) / "manifest.csv", index=False)
print("Сохранён отфильтрованный manifest для взрослых:", Path(FILTERED_DEST_ROOT_ADULTS) / "manifest.csv")
# Out:
# Сохранён отфильтрованный manifest для подростков: Athena_flat_filtered/cohort_teen_participants/manifest.csv
# Сохранён отфильтрованный manifest для взрослых: Athena_flat_filtered/cohort_adult_participants/manifest.csv

# %%
# скопируем файлы .npy для подростков
for _, row in filtered_manifest_teen.iterrows():
    npy_src = Path(row['npy_path'])
    participant_id = row['participant_id']
    out_sub = Path(FILTERED_DEST_ROOT_TEENS) / participant_id
    ensure_dir(out_sub)
    npy_dst = out_sub / npy_src.name
    if not npy_dst.exists():
        shutil.copy2(npy_src, npy_dst)

# %%
# Скопируем файлы .npy для взрослых
for _, row in filtered_manifest_adult.iterrows():
    npy_src = Path(row['npy_path'])
    participant_id = row['participant_id']
    out_sub = Path(FILTERED_DEST_ROOT_ADULTS) / participant_id
    ensure_dir(out_sub)
    npy_dst = out_sub / npy_src.name
    if not npy_dst.exists():
        shutil.copy2(npy_src, npy_dst)
